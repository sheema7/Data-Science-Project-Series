# %% [markdown]
# Exploratory Data Analysis(EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('infolimpioavanzadoTarget.csv')
data
# Out:
#             date       open       high        low      close   adjclose  \
# 0     2022-01-03  17.799999  18.219000  17.500000  17.760000  17.760000
# 1     2022-01-04  17.700001  18.309999  17.620001  17.660000  17.660000
# 2     2022-01-05  17.580000  17.799999  16.910000  16.950001  16.950001
# 3     2022-01-06  16.650000  16.879999  16.139999  16.170000  16.170000
# 4     2022-01-07  16.219999  16.290001  15.630000  15.710000  15.710000
# ...          ...        ...        ...        ...        ...        ...
# 7776  2022-12-23  23.250000  23.540001  23.250000  23.290001  22.699928
# 7777  2022-12-27  23.350000  23.610001  23.250000  23.350000  22.758406
# 7778  2022-12-28  23.450001  23.570000  23.219999  23.350000  22.758406
# 7779  2022-12-29  23.330000  23.740000  23.330000  23.610001  23.011820
# 7780  2022-12-30  23.680000  23.760000  23.610001  23.610001  23.011820
#
#       volume ticker  RSIadjclose15  RSIvolume15  ...    high-15       K-15  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7781 entries, 0 to 7780
# Columns: 1285 entries, date to TARGET
# dtypes: float64(1280), int64(3), object(2)
# memory usage: 76.3+ MB

# %%
data.shape
# Out:
# (7781, 1285)

# %%
data.head()
# Out:
#          date       open       high        low      close   adjclose  volume  \
# 0  2022-01-03  17.799999  18.219000  17.500000  17.760000  17.760000  106600
# 1  2022-01-04  17.700001  18.309999  17.620001  17.660000  17.660000  128700
# 2  2022-01-05  17.580000  17.799999  16.910000  16.950001  16.950001  103100
# 3  2022-01-06  16.650000  16.879999  16.139999  16.170000  16.170000  173600
# 4  2022-01-07  16.219999  16.290001  15.630000  15.710000  15.710000  137800
#
#   ticker  RSIadjclose15  RSIvolume15  ...  high-15  K-15  D-15  \
# 0   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 1   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 2   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 3   ASLE            NaN          NaN  ...      NaN   NaN   NaN
# 4   ASLE            NaN          NaN  ...      NaN   NaN   NaN
#
#    stochastic-k-15  stochastic-d-15  stochastic-kd-15  volumenrelativo  \
# ...

# %%
data.describe()
# Out:
#               open         high          low        close     adjclose  \
# count  7781.000000  7781.000000  7781.000000  7781.000000  7781.000000
# mean     34.990220    35.655999    34.301243    34.964414    34.483147
# std      99.841502   101.451058    98.073945    99.790823    98.603879
# min       0.410000     0.435000     0.405000     0.408000     0.408000
# 25%       4.050000     4.130000     3.980000     4.030000     3.960000
# 50%      10.080000    10.110000    10.005000    10.080000    10.061000
# 75%      24.350000    24.500000    24.080000    24.250000    22.466007
# max     795.739990   799.359985   784.960022   797.489990   783.376221
#
#              volume  RSIadjclose15  RSIvolume15  RSIadjclose25  RSIvolume25  \
# count  7.781000e+03    7316.000000  7316.000000    7006.000000  7006.000000
# mean   7.586022e+05      46.817434    49.814790      46.966016    49.898659
# std    3.934491e+06      11.672838     5.002664       8.760961     3.420371
# ...

# %%
data.tail()
# Out:
#             date       open       high        low      close   adjclose  \
# 7776  2022-12-23  23.250000  23.540001  23.250000  23.290001  22.699928
# 7777  2022-12-27  23.350000  23.610001  23.250000  23.350000  22.758406
# 7778  2022-12-28  23.450001  23.570000  23.219999  23.350000  22.758406
# 7779  2022-12-29  23.330000  23.740000  23.330000  23.610001  23.011820
# 7780  2022-12-30  23.680000  23.760000  23.610001  23.610001  23.011820
#
#       volume ticker  RSIadjclose15  RSIvolume15  ...    high-15       K-15  \
# 7776    4900   ATLO      60.782255    47.081752  ...  23.600000  26.223672
# 7777    9200   ATLO      62.022801    47.747952  ...  23.610001  30.764722
# 7778   15200   ATLO      62.022801    48.713225  ...  23.610001  30.764722
# 7779    7100   ATLO      67.186408    47.445460  ...  23.740000  46.457382
# 7780    7100   ATLO      67.186408    47.445460  ...  23.760000  45.784072
#
#            D-15  stochastic-k-15  stochastic-d-15  stochastic-kd-15  \
# ...

# %%
data.isnull()
# Out:
#        date   open   high    low  close  adjclose  volume  ticker  \
# 0     False  False  False  False  False     False   False   False
# 1     False  False  False  False  False     False   False   False
# 2     False  False  False  False  False     False   False   False
# 3     False  False  False  False  False     False   False   False
# 4     False  False  False  False  False     False   False   False
# ...     ...    ...    ...    ...    ...       ...     ...     ...
# 7776  False  False  False  False  False     False   False   False
# 7777  False  False  False  False  False     False   False   False
# 7778  False  False  False  False  False     False   False   False
# 7779  False  False  False  False  False     False   False   False
# 7780  False  False  False  False  False     False   False   False
#
#       RSIadjclose15  RSIvolume15  ...  high-15   K-15   D-15  stochastic-k-15  \
# 0              True         True  ...     True   True   True             True
# ...

# %%
data.isnull().sum()
# Out:
# date                  0
# open                  0
# high                  0
# low                   0
# close                 0
#                    ...
# stochastic-kd-15    587
# volumenrelativo     215
# diff                155
# INCREMENTO          155
# TARGET                0
# Length: 1285, dtype: int64

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# date                0
# open                0
# high                0
# low                 0
# close               0
#                    ..
# stochastic-kd-15    0
# volumenrelativo     0
# diff                0
# INCREMENTO          0
# TARGET              0
# Length: 1285, dtype: int64

# %%
data
# Out:
#             date       open       high        low      close   adjclose  \
# 98    2022-05-24  13.810000  14.120000  13.610000  14.100000  14.100000
# 99    2022-05-25  14.100000  14.320000  14.050000  14.180000  14.180000
# 100   2022-05-26  14.120000  14.347000  13.790000  13.820000  13.820000
# 101   2022-05-27  14.010000  14.250000  13.940000  14.110000  14.110000
# 102   2022-05-31  14.140000  14.140000  13.530000  13.860000  13.860000
# ...          ...        ...        ...        ...        ...        ...
# 7771  2022-12-16  22.700001  22.879999  22.500000  22.670000  22.095634
# 7772  2022-12-19  22.600000  22.799999  22.379999  22.600000  22.027409
# 7773  2022-12-20  22.600000  23.000000  22.600000  22.840000  22.261328
# 7774  2022-12-21  22.889999  23.389999  22.889999  23.309999  22.719419
# 7775  2022-12-22  23.330000  23.379999  23.049999  23.299999  22.709673
#
#       volume ticker  RSIadjclose15  RSIvolume15  ...  high-15       K-15  \
# ...

# %%
data.describe()
# Out:
#               open         high          low        close     adjclose  \
# count  4204.000000  4204.000000  4204.000000  4204.000000  4204.000000
# mean     33.992244    34.650412    33.374547    34.027746    33.673274
# std      94.458121    96.013023    93.045982    94.649359    93.931605
# min       0.420000     0.436000     0.405000     0.408000     0.408000
# 25%       3.410000     3.567500     3.290750     3.397500     3.397500
# 50%       8.980000     9.200000     8.675000     8.940000     8.810000
# 75%      23.500000    23.685000    23.288750    23.462499    22.035493
# max     642.979980   643.359985   617.570007   628.270020   625.082397
#
#              volume  RSIadjclose15  RSIvolume15  RSIadjclose25  RSIvolume25  \
# count  4.204000e+03    4204.000000  4204.000000    4204.000000  4204.000000
# mean   6.463908e+05      47.259799    49.839989      46.962077    49.902303
# std    1.524917e+06      10.966983     4.807620       8.324780     3.221936
# ...

# %%
correlation_matrix = data.corr()
correlation_matrix
# Out:
#                       open      high       low     close  adjclose    volume  \
# open              1.000000  0.999881  0.999907  0.999724  0.999710  0.038828
# high              0.999881  1.000000  0.999901  0.999912  0.999902  0.039719
# low               0.999907  0.999901  1.000000  0.999875  0.999851  0.038620
# close             0.999724  0.999912  0.999875  1.000000  0.999984  0.039548
# adjclose          0.999710  0.999902  0.999851  0.999984  1.000000  0.040067
# ...                    ...       ...       ...       ...       ...       ...
# stochastic-kd-15 -0.011758 -0.008796 -0.009462 -0.006114 -0.006165  0.021876
# volumenrelativo  -0.031200 -0.030572 -0.031384 -0.030836 -0.030756  0.483200
# diff             -0.051163 -0.049675 -0.052318 -0.049955 -0.049751  0.024289
# INCREMENTO       -0.005869 -0.005632 -0.006131 -0.005812 -0.005670 -0.036679
# TARGET            0.003500  0.004375  0.002912  0.003868  0.004603  0.052563
#
# ...

# %%
# Convert the date column to datetime
data['date'] = pd.to_datetime(data['date'])
# Plot the stock prices over time
plt.plot(data['date'], data['volumenrelativo'], color = 'grey')
plt.title('Stock Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.show()

# %%
plt.hist(data['date'], bins=20, color='gray', edgecolor='black')
plt.title('Distribution of Stock Prices')
plt.xlabel('Stock Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting volume trends over time
plt.figure(figsize=(14, 7))
plt.scatter(data['date'], data['volume'],label='Volume', color = 'gray')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Volume Trends Over Time')
plt.legend()
plt.show()

# %%
clean_data = data.dropna()

# %%
clean_data.isnull().sum()
# Out:
# date                0
# open                0
# high                0
# low                 0
# close               0
#                    ..
# stochastic-kd-15    0
# volumenrelativo     0
# diff                0
# INCREMENTO          0
# TARGET              0
# Length: 1285, dtype: int64

# %% [markdown]
# Predictive Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
X = data[['open', 'high', 'low', 'volume', 'RSIadjclose15', 'RSIvolume15']]
y = data['TARGET']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 40, test_size = 0.5)

# %%
scaler = StandardScaler()
X_trains = scaler.fit_transform(X_train)
X_tests = scaler.transform(X_test)

# %%
# Build a linear regression model
model = LinearRegression()
model.fit(X_trains, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_tests)

# %%
y_pred
# Out:
# array([0.17794183, 0.21854823, 0.268975  , ..., 0.1722595 , 0.14902203,
#        0.24380732])

# %%
plt.scatter(y_test, y_pred, color = 'gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()
